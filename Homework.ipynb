# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Mahmood Alkhatieb**

# %% [markdown]
# _im intrested in notebook because its the future_

# %% [markdown]
# ### adds one plus one

# %%
1 + 1
# Out:
# 2

# %% [markdown]
# - bullet
# | Heading | Heading |
# | ----| ----|
# | text   | text |
# | text | text |
#
# https://www.ibm.com/docs/en/wsd?topic=notebook-markdown-cheatsheet
